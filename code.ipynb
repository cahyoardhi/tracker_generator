# %% [markdown]
# # **EVENT GENERATOR**
# goals: to reduce time during creating events
#
# event available to use (for now):
# 1. screen_view | trigger on page load
# 2. button_click | trigger on button click
# 3. section_click | trigger on see all / open new section
# 4. view_item_list | trigger on product list view
# 5. select_item | trigger on click item
# 6. view_item | trigger on PDP

# %%
from function_list import *

# %%
# EMERGENCY INPUT FIELD
screen_name = "Shop - Other Services - Orbit"
event_name = "promotion_click"
event_category = "General Shop"
promotion_brand = "Orbit"
promotion_id = "12345-id-of-promotion"
promotion_name = "Package Orbit banner"
promotion_list_name = "Other Services - Orbit"
promotion_position = "1"
promotion_type = "banner"
index = 1

# %%
# OFFICIAL INPUT FIELD
event_name = "select_item"  # General
screen_name = "Shop - Other Services - Prabayar"  # General
event_category = "General Shop"  # General

list_name = "Device Bundling"  # section_click

button_name = "One"  # button_click
button_purpose = "open services available"  # button_click

promotion_brand = "Prabayar"  # promotion_click
promotion_id = "12345-id-of-promotion"  # promotion_click
promotion_name = "Package one banner"  # promotion_click
promotion_list_name = "Other Services - Prabayar"  # promotion_click
promotion_position = "1"  # promotion_click
promotion_type = "banner"  # promotion_click
index = 1  # promotion_click

item_list_id = ""  # ecommerce
item_list_name = promotion_list_name  # ecommerce
item_id = "123-id-item"  # ecommerce
item_name = "Pre order samsung galaxy z fold 6"  # ecommerce
item_category = "bundling"  # ecommerce
item_variant = "bundling"  # ecommerce
item_brand = promotion_brand  # ecommerce
item_price = 28499000  # ecommerce

# %%
# DO NOT CHANGE ANY CONFIG HERE
if event_name == "promotion_click":

    generate_promotion_click(
        event_name,
        event_category,
        promotion_brand,
        promotion_id,
        promotion_name,
        promotion_list_name,
        promotion_position,
        promotion_type,
        screen_name,
        index,
    )



elif event_name == "view_item_list":
    generate_view_item_list(
        event_name,
        event_category,
        screen_name,
        item_list_id,
        item_list_name,
        item_id,
        item_name,
        item_category,
        item_variant,
        item_brand,
        item_price,
    )
elif event_name == "select_item" or event_name == "view_item":

    generate_select_item_and_view_item(
        event_name,
        event_category,
        screen_name,
        item_list_id,
        item_list_name,
        item_id,
        item_name,
        item_category,
        item_variant,
        item_brand,
        item_price,
    )



elif event_name == "button_click":

    generate_button_click(
        event_name, event_category, button_name, button_purpose, screen_name
    )



elif event_name == "section_click":

    generate_section_click(
        event_name=event_name,

        event_category=event_category,
        screen_name=screen_name,
        list_name=list_name,

    )
elif event_name == "screen_view":
    generate_screen_view(event_name=event_name, screen_name=screen_name)
# Out:
# // ANDROID
# val promoParams = Bundle().apply {
# params.putString("event_category","General Shop");
# params.putString("promotion_brand","Orbit"); // dynamic value
# params.putString("promotion_id","12345-id-of-promotion"); // dynamic value // mandatory value
# params.putString("promotion_name","Package Orbit banner"); // dynamic value // set empty string if null
# params.putString("promotion_list_name","Other Services - Orbit");  // dynamic value // set empty string if null
# params.putString("promotion_position","1"); // dynamic value // set 1 if null
# params.putString("promotion_type","banner"); // dynamic value //set empty string if null
# params.putString("index", "1");
# params.putString(Param.SCREEN_NAME,"Shop - Other Services - Orbit"); // mandatory value
# }
#
# firebaseAnalytics.logEvent("promotion_click", promoParams)
#
#
# // IOS
# Analytics.logEvent("promotion_click", parameters: [
# "event_category":"General Shop",
# ...
